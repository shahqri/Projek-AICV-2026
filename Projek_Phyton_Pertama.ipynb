# %% [markdown]
# <a href="https://colab.research.google.com/github/shahqri/Projek-AICV-2026/blob/main/Projek_Phyton_Pertama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Dunia IT!")
print("Selamat Datang!")
# Out:
# Hello, Dunia IT!
# Selamat Datang!

# %%
nama = "Aishah"
umur = 19
Tahun_Lahir = 2026 - umur

print("Nama saya", nama, "dan saya lahir tahun", Tahun_Lahir)
# Out:
# Nama saya Aishah dan saya lahir tahun 2007

# %%
nama_pelajar = input("Sila masukkan nama anda : ")
hobi = input("Apakah hobi anda?")

print(f"Oh, {hobi} tu sangat menarik, {nama_pelajar}!")
# Out:
# Sila masukkan nama anda : Aishah
# Apakah hobi anda?membaca
# Oh, membaca tu sangat menarik, Aishah!

# %%
nama = input("Sila masukkan nama anda : ")
umur = input("Sila masukkan umur anda : ")
tempat_tinggal = input("Sila masukkan tempat tinggal anda : ")

print(f"Nama saya {nama}, berumur {umur} dan berasal daripada {tempat_tinggal}. Selamat berkenalan!")
# Out:
# Sila masukkan nama anda : Aishah
# Sila masukkan umur anda : 19
# Sila masukkan tempat tinggal anda : PUlau PInang
# Nama saya Aishah, berumur 19 dan berasal daripada PUlau PInang. Selamat berkenalan!

# %%
tahun_lahir = int(input("Tahun lahir anda : "))
umur = 2026 - tahun_lahir

print(f"Umur anada dalam tahun 2026 ialah {umur} tahun.")
# Out:
# Tahun lahir anda : 2007
# Umur anada dalam tahun 2026 ialah 19 tahun.

# %%
mood = input("Perasaan anda hari ini? (happy/sad) : ")

if mood == "happy" :
  print("Baguslah! Teruskan kecemerlangan.")
else :
  print("Jangan sedih, esok pasti lebih baik!")
# Out:
# Perasaan anda hari ini? (happy/sad) : sad
# Jangan sedih, esok pasti lebih baik!

# %% [markdown]
# # New Section

# %%
import random

# Komputer pilih nombor rawak antara 1 hingga 20
nombor_rahsia = random.randint(1, 20)
tekaan = 0

print("Jom main! Saya dah pilih satu nombor antara 1 hingga 20.")

# Gelung akan berjalan selagi tekaan salah
while tekaan != nombor_rahsia:
    tekaan = int(input("Masukkan tekaan anda: "))

    if tekaan < nombor_rahsia:
        print("Terlalu rendah! Cuba lagi.")
    elif tekaan > nombor_rahsia:
        print("Terlalu tinggi! Cuba lagi.")
    else:
        print("Tahniah! Tekaan anda betul! ")
# Out:
# Jom main! Saya dah pilih satu nombor antara 1 hingga 20.
# Masukkan tekaan anda: 1
# Terlalu rendah! Cuba lagi.
# Masukkan tekaan anda: 10
# Terlalu tinggi! Cuba lagi.
# Masukkan tekaan anda: 7
# Terlalu tinggi! Cuba lagi.
# Masukkan tekaan anda: 5
# Terlalu tinggi! Cuba lagi.
# Masukkan tekaan anda: 3
# Terlalu rendah! Cuba lagi.
# Masukkan tekaan anda: 4
# Tahniah! Tekaan anda betul!

# %% [markdown]
# # New Section

# %% [markdown]
# ## **Kalkulator Umur Kucing**

# %%
print("--- KALKULATOR UMUR KUCING ---")

# Ambil input nama dan umur kucing
nama_kucing = input("Masukkan nama kucing anda: ")
umur_manusia = input("Masukkan umur kucing tersebut (dalam tahun manusia): ")

# Tukar input teks (str) kepada nombor (int) untuk dikira
umur_int = int(umur_manusia)

# Formula mudah: 1 tahun manusia bersamaan 7 tahun kucing
umur_kucing = umur_int * 7

print(f"Wah, umur {nama_kucing} dalam tahun kucing adalah {umur_kucing} tahun! ")
# Out:
# --- KALKULATOR UMUR KUCING ---
# Masukkan nama kucing anda: Hayderr
# Masukkan umur kucing tersebut (dalam tahun manusia): 3
# Wah, umur Hayderr dalam tahun kucing adalah 21 tahun!
